# %%
import pandas as pd
import matplotlib.pyplot as plt
from readeplus_sql import *
from dateutil.parser import parse

# %%
df = read_eplusql("../osm/clase_006/cubos_003/run/eplusout.sql",read='all')
# df = read_eplusql("../osm/clase_006/cubos_003/run/eplusout.sql",read='data')
# df = read_eplusql("../osm/clase_006/cubos_003/run/eplusout.sql",read='construction')

# %%
sc = df.construction_systems
sc
# Out:
# array(['ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 4',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 5',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 6',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 7-8', 'EXTERIOR DOOR',
#        'INTERIOR CEILING', 'INTERIOR FLOOR', 'INTERIOR WALL',
#        'INTERIOR DOOR', 'INTERIOR PARTITION',
#        'EXTSLABCARPET 4IN CLIMATEZONE 1-8',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2-5',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 4',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 7-8',
#        'ASHRAE 189.1-2009 EXTROOF METAL CLIMATEZONE 6', 'INTERIOR WINDOW',
# ...

# %%
df.get_construction(['ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1'])
# Out:
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1
# Total thickness    :0.275 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_66bce_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_66bce_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_66bce_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_66bce_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_66bce_row0_col3" class="data row0 col3" >837.000000</td>
# ...

# %%
df.vars
# Out:
# array(['Environment:Site Outdoor Air Drybulb Temperature (C)',
#        ':Electricity:Facility (J)',
#        'THERMAL ZONE 1:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE 2:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE 3:Zone Mean Air Temperature (C)',
#        'THERMAL ZONE 1:Zone Air Temperature (C)',
#        'THERMAL ZONE 1:Zone Air Relative Humidity (%)',
#        'THERMAL ZONE 2:Zone Air Temperature (C)',
#        'THERMAL ZONE 2:Zone Air Relative Humidity (%)',
#        'THERMAL ZONE 3:Zone Air Temperature (C)',
#        'THERMAL ZONE 3:Zone Air Relative Humidity (%)'], dtype=object)

# %%
variables = ['Mean',"Site"]
data = df.get_data(variables)

# %%
data.plot(subplots=True,figsize=(20,10))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>],
#       dtype=object)
